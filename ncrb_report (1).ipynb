# %%
import numpy as np
import pandas as pd
import tabula 
import jpype

# %%
doc=tabula.read_pdf("NCRB_STATS.pdf",pages="all",multiple_tables=True,encoding="latin-1")
# Out:
# ---------------------------------------------------------------------------
# JVMNotFoundException                      Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 doc=tabula.read_pdf("NCRB_STATS.pdf",pages="all",multiple_tables=True,encoding="latin-1")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\tabula\io.py:400, in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, use_raw_url, pages, guess, area, relative_area, lattice, stream, password, silent, columns, relative_columns, format, batch, output_path, force_subprocess, options)
#     397     raise ValueError(f"{path} is empty. Check the file, or download it manually.")
#     399 try:
# --> 400     output = _run(
#     401         tabula_options,
#     402         java_options,
#     403         path,
#     404         encoding=encoding,
#     405         force_subprocess=force_subprocess,
#     406     )
#     407 finally:
# ...

# %%
# no. of tables
print(type(doc))
print(len(doc))

# %%
doc[37].head()

# %%
#getting tables 
for i in range(20):
    print(f"\nTable {i}")
    print(doc[i].shape)

# %%
#filtering out junk tables
for i, table in enumerate(doc):
    if len(table) > 20:  # more than 20 rows
        print(f"Table {i}: {table.shape}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #filtering out junk tables
# ----> 2 for i, table in enumerate(doc):
#       3     if len(table) > 20:  # more than 20 rows
#       4         print(f"Table {i}: {table.shape}")
#
# NameError: name 'doc' is not defined

# %%
type(doc[37])
# Out:
# pandas.core.frame.DataFrame

# %%
doc[7]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 doc[7]
#
# NameError: name 'doc' is not defined
